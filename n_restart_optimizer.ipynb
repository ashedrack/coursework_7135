# %%
# Version 1: Fixed kernel and n_restart_optimizer

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern
from sklearn.model_selection import train_test_split

np.random.seed(1)

# Load data
df = pd.read_csv('kc_house_data.csv')

# Select relevant features
dfn = df[['bathrooms', 'sqft_living']]

# Split data
dfn2 = df.iloc[20000:]
X = dfn2[['bathrooms', 'sqft_living']]
y = dfn2['price']

# Plotting histograms for all columns
num_cols = len(df.columns)
num_rows = (num_cols + 2) // 3  # Adjust number of rows based on the number of columns
plt.figure(figsize=(12, 4 * num_rows))
for i, col in enumerate(df.columns):
    plt.subplot(num_rows, 3, i + 1)
    sns.histplot(data=df, x=col, kde=True)
plt.tight_layout()
plt.show()

# %%
# Option 1: Remove rows with missing values
df_cleaned = df.dropna()
#df_cleaned = df.fillna(df.mean())

# %%
# Check for missing values
df_cleaned = df.isnull().sum()
print("Missing values:")
print(df_cleaned)
# Out:
# Missing values:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Select relevant features
dfn = df[['bathrooms', 'sqft_living', 'price']]
dfn2 = dfn.iloc[20000:]
dfn3 = dfn2[['bathrooms', 'sqft_living']]

# Features and target
X = dfn3
y = dfn2['price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=101)

# Define kernels
kernels = [
    1.0 * RBF(length_scale=0.5, length_scale_bounds=(1e-05, 100000.0)),
    1.0 * RationalQuadratic(length_scale=0.5, alpha=0.1),
    1.0 * ExpSineSquared(length_scale=0.5, periodicity=3.0,
                         length_scale_bounds=(1e-05, 100000.0),
                         periodicity_bounds=(1.0, 10.0)),
    ConstantKernel(0.1, (0.01, 10.0)) * (DotProduct(sigma_0=1.0, sigma_0_bounds=(0.1, 10.0)) ** 2),
    1.0 ** 2 * Matern(length_scale=0.5, length_scale_bounds=(1e-05, 100000.0), nu=0.5)
]

# Number of restarts for the optimizer
n_restarts = np.arange(0, 10, 3)

# Loop through each kernel and number of restarts
for kernel in kernels:
    for i in n_restarts:
        # Specify Gaussian Process parameters
        if isinstance(kernel, ExpSineSquared):
            alpha = 1.0
        elif isinstance(kernel, ConstantKernel) and isinstance(kernel.k2, DotProduct):
            alpha = 1.0
        else:
            alpha = 1.0

        # Gaussian Process Regressor
        gp = GaussianProcessRegressor(kernel=kernel, alpha=alpha, optimizer='fmin_l_bfgs_b',
                                      n_restarts_optimizer=i, normalize_y=False,
                                      copy_X_train=True, random_state=2016)
        try:
            # Fit the model
            gp.fit(X_train, y_train)

            # Make predictions
            y_pred, sigma = gp.predict(X_test, return_std=True)

            # Plotting
            fig, ax = plt.subplots(figsize=(6, 4))
            plt.scatter(X_test['sqft_living'], y_pred, color='red', label='GPR prediction')
            plt.scatter(X_test['sqft_living'], y_test, color='blue', label='y_test')

            # Regression plot using seaborn
            sns.regplot(x=X_test['sqft_living'], y=y_pred, scatter=False, label='GPR Reg_plot', ax=ax)

            # Labels and title
            plt.xlabel('Sqft_living')
            plt.ylabel('Price')
            plt.title(f'Kernel: {kernel}')
            plt.suptitle(f'N_restarts: {i}')
            plt.legend()
            plt.tight_layout()

            # Show the plot
            plt.show()
        except np.linalg.LinAlgError as e:
            print(f"LinAlgError for kernel: {kernel} with n_restarts_optimizer: {i}. Error: {e}")
# Out:
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# LinAlgError for kernel: 1**2 * ExpSineSquared(length_scale=0.5, periodicity=3) with n_restarts_optimizer: 0. Error: ("The kernel, 1**2 * ExpSineSquared(length_scale=0.5, periodicity=3), is not returning a positive definite matrix. Try gradually increasing the 'alpha' parameter of your GaussianProcessRegressor estimator.", '98-th leading minor of the array is not positive definite')
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__periodicity is close to the specified upper bound 10.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\_gpr.py:477: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\_gpr.py:477: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__kernel__sigma_0 is close to the specified upper bound 10.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__kernel__sigma_0 is close to the specified upper bound 10.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\wrksy\miniconda3\envs\projects\Lib\site-packages\sklearn\gaussian_process\kernels.py:455: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
